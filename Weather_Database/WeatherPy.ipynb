# %%
# import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
# use the citipy module to determine city based on latitude and longitude

from citipy import citipy

# %%
# create a list for holding the cities

cities = []

# identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %%
# import the requests library

import requests

# import the API key

from config import weather_api_key

# %%
# starting URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4b9355c769741853224a6827bf780486

# %%
# import the datetime module from the datetime library

from datetime import datetime

# %%
# create an empty list to hold the weather data

city_data = []

# print the beginning of the logging

print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters

record_count = 1
set_count = 1

# loop through all the cities in the list

for i, city in enumerate(cities):

    # group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # create endpoint URL with each city
    
    city_url = url + "&q=" + city.replace(" ","+")

    # log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # add 1 to the record count
    
    record_count += 1
    
    # run an API request for each of the cities
    
    try:
        # parse the JSON and retrieve data
        
        city_weather = requests.get(city_url).json()
        
        # parse out the needed data
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # append the city information into city_data list
        
        city_data.append({"City": city.title(),
                          "Current Description": city_description,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # if an error is experienced, skip the city
    
    except:
        print("City not found. Skipping...")
        pass

# indicate that Data Loading is complete

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | porto belo
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | santa helena de goias
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | ojinaga
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | ust-koksa
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | la asuncion
# Processing Record 24 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | salinas
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | ciudad bolivar
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | saint-pierre
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 1 | ialibu
# Processing Record 35 of Set 1 | aden
# Processing Record 36 of Set 1 | marsh harbour
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | henties bay
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | kanchanaburi
# Processing Record 48 of Set 1 | papara
# Processing Record 49 of Set 1 | vostok
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | maniitsoq
# Processing Record 2 of Set 2 | romitan
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | gujranwala
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | dergaon
# Processing Record 13 of Set 2 | peniche
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | isangel
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 2 | hofn
# Processing Record 24 of Set 2 | thap than
# Processing Record 25 of Set 2 | wuwei
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | staraya mayna
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | parsabad
# Processing Record 30 of Set 2 | ternate
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | chengdu
# Processing Record 34 of Set 2 | le moule
# Processing Record 35 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 2 | alta floresta
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | agadir
# Processing Record 40 of Set 2 | othaya
# Processing Record 41 of Set 2 | bidor
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | rincon
# Processing Record 45 of Set 2 | hay river
# Processing Record 46 of Set 2 | meulaboh
# Processing Record 47 of Set 2 | chaiya
# Processing Record 48 of Set 2 | gambela
# Processing Record 49 of Set 2 | panguna
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | sorong
# Processing Record 2 of Set 3 | burica
# City not found. Skipping...
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | ketchikan
# Processing Record 6 of Set 3 | talcahuano
# Processing Record 7 of Set 3 | tazovskiy
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | verkhnyaya inta
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | cururupu
# Processing Record 12 of Set 3 | poso
# Processing Record 13 of Set 3 | soyo
# Processing Record 14 of Set 3 | labuhan
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | umm kaddadah
# Processing Record 18 of Set 3 | vacaria
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | dwarka
# Processing Record 22 of Set 3 | buritis
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | kedrovyy
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | yagodnoye
# Processing Record 27 of Set 3 | antofagasta
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | mineiros
# Processing Record 33 of Set 3 | yaan
# Processing Record 34 of Set 3 | forecariah
# Processing Record 35 of Set 3 | san joaquin
# Processing Record 36 of Set 3 | kralendijk
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | lugovskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | valparaiso
# Processing Record 40 of Set 3 | camacha
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | shashi
# Processing Record 46 of Set 3 | ribeira brava
# Processing Record 47 of Set 3 | akkermanovka
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | salalah
# Processing Record 50 of Set 3 | canon city
# Processing Record 1 of Set 4 | puerto triunfo
# Processing Record 2 of Set 4 | marsa matruh
# Processing Record 3 of Set 4 | kargasok
# Processing Record 4 of Set 4 | kamenka
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | campbell river
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | ningxiang
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | bjala
# City not found. Skipping...
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | kieta
# Processing Record 15 of Set 4 | teruel
# Processing Record 16 of Set 4 | lakes entrance
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | belmonte
# Processing Record 19 of Set 4 | saysain
# Processing Record 20 of Set 4 | cartagena del chaira
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | kloulklubed
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | mogadishu
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | saint-francois
# Processing Record 29 of Set 4 | chifeng
# Processing Record 30 of Set 4 | san ramon de la nueva oran
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | bluff
# Processing Record 33 of Set 4 | saint anthony
# Processing Record 34 of Set 4 | along
# Processing Record 35 of Set 4 | sloboda
# Processing Record 36 of Set 4 | wajir
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | puerto escondido
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | crixas
# Processing Record 41 of Set 4 | normandin
# Processing Record 42 of Set 4 | vila franca do campo
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | buraydah
# Processing Record 45 of Set 4 | pacific grove
# Processing Record 46 of Set 4 | kirakira
# Processing Record 47 of Set 4 | puerto rico
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | komsomolskiy
# Processing Record 50 of Set 4 | makakilo city
# Processing Record 1 of Set 5 | biloela
# Processing Record 2 of Set 5 | effingham
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | staryy nadym
# Processing Record 5 of Set 5 | tezu
# Processing Record 6 of Set 5 | jalu
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | lillooet
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | zhigansk
# Processing Record 11 of Set 5 | koundara
# Processing Record 12 of Set 5 | monrovia
# Processing Record 13 of Set 5 | castro
# Processing Record 14 of Set 5 | lingao
# Processing Record 15 of Set 5 | shahrud
# Processing Record 16 of Set 5 | vostochnyy
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | waipawa
# Processing Record 20 of Set 5 | latung
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | polunochnoye
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | baijiantan
# Processing Record 26 of Set 5 | powell
# Processing Record 27 of Set 5 | saskylakh
# Processing Record 28 of Set 5 | dapaong
# Processing Record 29 of Set 5 | stykkisholmur
# Processing Record 30 of Set 5 | bururi
# Processing Record 31 of Set 5 | gari
# Processing Record 32 of Set 5 | adrar
# Processing Record 33 of Set 5 | arlit
# Processing Record 34 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | buala
# Processing Record 38 of Set 5 | pacifica
# Processing Record 39 of Set 5 | quatre cocos
# Processing Record 40 of Set 5 | darhan
# Processing Record 41 of Set 5 | requena
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | liverpool
# Processing Record 44 of Set 5 | kemijarvi
# Processing Record 45 of Set 5 | dongsheng
# Processing Record 46 of Set 5 | angicos
# Processing Record 47 of Set 5 | matara
# Processing Record 48 of Set 5 | sassandra
# Processing Record 49 of Set 5 | vao
# Processing Record 50 of Set 5 | canutama
# Processing Record 1 of Set 6 | hede
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | padang
# Processing Record 5 of Set 6 | tiznit
# Processing Record 6 of Set 6 | kamiiso
# Processing Record 7 of Set 6 | port blair
# Processing Record 8 of Set 6 | yei
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | alekseyevsk
# Processing Record 11 of Set 6 | kinsale
# Processing Record 12 of Set 6 | varel
# Processing Record 13 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 6 | slave lake
# Processing Record 15 of Set 6 | bonfim
# Processing Record 16 of Set 6 | saurimo
# Processing Record 17 of Set 6 | buin
# Processing Record 18 of Set 6 | southbridge
# Processing Record 19 of Set 6 | akyab
# Processing Record 20 of Set 6 | turayf
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | praia
# Processing Record 23 of Set 6 | kjollefjord
# Processing Record 24 of Set 6 | uvalde
# Processing Record 25 of Set 6 | christchurch
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | youghal
# Processing Record 28 of Set 6 | byron bay
# Processing Record 29 of Set 6 | pasni
# Processing Record 30 of Set 6 | calvinia
# Processing Record 31 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 6 | sabang
# Processing Record 33 of Set 6 | peace river
# Processing Record 34 of Set 6 | kostolac
# Processing Record 35 of Set 6 | ekhabi
# Processing Record 36 of Set 6 | ossora
# Processing Record 37 of Set 6 | camana
# Processing Record 38 of Set 6 | kavaratti
# Processing Record 39 of Set 6 | mingaora
# Processing Record 40 of Set 6 | hami
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | mtambile
# Processing Record 43 of Set 6 | bani walid
# Processing Record 44 of Set 6 | fortuna
# Processing Record 45 of Set 6 | kodinsk
# Processing Record 46 of Set 6 | bethel
# Processing Record 47 of Set 6 | sarankhola
# Processing Record 48 of Set 6 | quime
# Processing Record 49 of Set 6 | copiapo
# Processing Record 50 of Set 6 | sebinkarahisar
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | tessalit
# Processing Record 3 of Set 7 | senador guiomard
# Processing Record 4 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 7 | airai
# Processing Record 6 of Set 7 | velika gorica
# Processing Record 7 of Set 7 | jaggayyapeta
# Processing Record 8 of Set 7 | goderich
# Processing Record 9 of Set 7 | limon
# Processing Record 10 of Set 7 | petauke
# Processing Record 11 of Set 7 | darnah
# Processing Record 12 of Set 7 | sola
# Processing Record 13 of Set 7 | wawa
# Processing Record 14 of Set 7 | onega
# Processing Record 15 of Set 7 | shelburne
# Processing Record 16 of Set 7 | chikhli
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | gamba
# Processing Record 19 of Set 7 | port macquarie
# Processing Record 20 of Set 7 | lata
# Processing Record 21 of Set 7 | bitam
# Processing Record 22 of Set 7 | faanui
# Processing Record 23 of Set 7 | evanston
# Processing Record 24 of Set 7 | san ramon
# Processing Record 25 of Set 7 | zhangjiakou
# Processing Record 26 of Set 7 | banjar
# Processing Record 27 of Set 7 | brae
# Processing Record 28 of Set 7 | labis
# Processing Record 29 of Set 7 | poum
# Processing Record 30 of Set 7 | carmen
# Processing Record 31 of Set 7 | marystown
# Processing Record 32 of Set 7 | abeche
# Processing Record 33 of Set 7 | izumo
# Processing Record 34 of Set 7 | banyo
# Processing Record 35 of Set 7 | pangnirtung
# Processing Record 36 of Set 7 | nouakchott
# Processing Record 37 of Set 7 | hun
# Processing Record 38 of Set 7 | am timan
# Processing Record 39 of Set 7 | miraflores
# Processing Record 40 of Set 7 | kenora
# Processing Record 41 of Set 7 | palmer
# Processing Record 42 of Set 7 | hervey bay
# Processing Record 43 of Set 7 | ponta delgada
# Processing Record 44 of Set 7 | limbang
# Processing Record 45 of Set 7 | ewa beach
# Processing Record 46 of Set 7 | youkounkoun
# Processing Record 47 of Set 7 | porto walter
# Processing Record 48 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 7 | garm
# City not found. Skipping...
# Processing Record 50 of Set 7 | hamilton
# Processing Record 1 of Set 8 | bereda
# Processing Record 2 of Set 8 | ehingen
# Processing Record 3 of Set 8 | kodiak
# Processing Record 4 of Set 8 | sawtell
# Processing Record 5 of Set 8 | mamakan
# Processing Record 6 of Set 8 | teya
# Processing Record 7 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 8 | dobryanka
# Processing Record 9 of Set 8 | sambava
# Processing Record 10 of Set 8 | marzuq
# Processing Record 11 of Set 8 | jiwani
# Processing Record 12 of Set 8 | saint-augustin
# Processing Record 13 of Set 8 | tarko-sale
# Processing Record 14 of Set 8 | mankono
# Processing Record 15 of Set 8 | tarija
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | aksu
# Processing Record 18 of Set 8 | olinda
# Processing Record 19 of Set 8 | tutoia
# Processing Record 20 of Set 8 | bowen
# Processing Record 21 of Set 8 | tangzhai
# Processing Record 22 of Set 8 | belaya gora
# Processing Record 23 of Set 8 | menongue
# Processing Record 24 of Set 8 | sibolga
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | doka
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | chiredzi
# Processing Record 29 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | manavalakurichi
# Processing Record 31 of Set 8 | caxito
# Processing Record 32 of Set 8 | vestmannaeyjar
# Processing Record 33 of Set 8 | rawson
# Processing Record 34 of Set 8 | abu dhabi
# Processing Record 35 of Set 8 | hobyo
# Processing Record 36 of Set 8 | machilipatnam
# Processing Record 37 of Set 8 | champerico
# Processing Record 38 of Set 8 | kaeo
# Processing Record 39 of Set 8 | kupang
# Processing Record 40 of Set 8 | vermillion
# Processing Record 41 of Set 8 | matagami
# Processing Record 42 of Set 8 | idaho falls
# Processing Record 43 of Set 8 | nanakuli
# Processing Record 44 of Set 8 | ust-barguzin
# Processing Record 45 of Set 8 | pirgos
# Processing Record 46 of Set 8 | longyearbyen
# Processing Record 47 of Set 8 | lavrentiya
# Processing Record 48 of Set 8 | oktyabrskiy
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 9 | cockburn town
# Processing Record 2 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 9 | hurghada
# Processing Record 4 of Set 9 | cape girardeau
# Processing Record 5 of Set 9 | lompoc
# Processing Record 6 of Set 9 | esperance
# Processing Record 7 of Set 9 | tigil
# Processing Record 8 of Set 9 | nortelandia
# Processing Record 9 of Set 9 | liminangcong
# City not found. Skipping...
# Processing Record 10 of Set 9 | natchitoches
# Processing Record 11 of Set 9 | moyale
# Processing Record 12 of Set 9 | visconde do rio branco
# Processing Record 13 of Set 9 | cidreira
# Processing Record 14 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 9 | northam
# Processing Record 16 of Set 9 | buta
# Processing Record 17 of Set 9 | necochea
# Processing Record 18 of Set 9 | amio
# Processing Record 19 of Set 9 | aktash
# Processing Record 20 of Set 9 | bone
# Processing Record 21 of Set 9 | hirara
# Processing Record 22 of Set 9 | sergeyevka
# Processing Record 23 of Set 9 | sistranda
# Processing Record 24 of Set 9 | shimoda
# Processing Record 25 of Set 9 | kabo
# Processing Record 26 of Set 9 | katobu
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | geraldton
# Processing Record 29 of Set 9 | aksarka
# Processing Record 30 of Set 9 | prado
# Processing Record 31 of Set 9 | manicaragua
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | banda aceh
# Processing Record 34 of Set 9 | aswan
# Processing Record 35 of Set 9 | carutapera
# Processing Record 36 of Set 9 | wukari
# Processing Record 37 of Set 9 | puerto leguizamo
# Processing Record 38 of Set 9 | avera
# Processing Record 39 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 9 | bima
# Processing Record 41 of Set 9 | severobaykalsk
# Processing Record 42 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 9 | lebu
# Processing Record 44 of Set 9 | zeya
# Processing Record 45 of Set 9 | beidao
# Processing Record 46 of Set 9 | el carmen
# Processing Record 47 of Set 9 | dali
# Processing Record 48 of Set 9 | deogarh
# Processing Record 49 of Set 9 | cumra
# Processing Record 50 of Set 9 | derzhavinsk
# Processing Record 1 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 10 | talnakh
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | santa rosa
# Processing Record 5 of Set 10 | havoysund
# Processing Record 6 of Set 10 | pirapora
# Processing Record 7 of Set 10 | patacamaya
# Processing Record 8 of Set 10 | alamogordo
# Processing Record 9 of Set 10 | havelock
# Processing Record 10 of Set 10 | chicama
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | cedar falls
# Processing Record 13 of Set 10 | nadym
# Processing Record 14 of Set 10 | mmabatho
# Processing Record 15 of Set 10 | karakol
# Processing Record 16 of Set 10 | pahalgam
# Processing Record 17 of Set 10 | elbeuf
# Processing Record 18 of Set 10 | riachao do dantas
# Processing Record 19 of Set 10 | phangnga
# Processing Record 20 of Set 10 | clyde river
# Processing Record 21 of Set 10 | lubango
# Processing Record 22 of Set 10 | lanigan
# Processing Record 23 of Set 10 | havre-saint-pierre
# Processing Record 24 of Set 10 | keita
# Processing Record 25 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 10 | lensk
# Processing Record 27 of Set 10 | graaff-reinet
# Processing Record 28 of Set 10 | taltal
# Processing Record 29 of Set 10 | grand island
# Processing Record 30 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 10 | batagay-alyta
# Processing Record 32 of Set 10 | hanting
# Processing Record 33 of Set 10 | isla vista
# Processing Record 34 of Set 10 | gorontalo
# Processing Record 35 of Set 10 | richards bay
# Processing Record 36 of Set 10 | aklavik
# Processing Record 37 of Set 10 | lufkin
# Processing Record 38 of Set 10 | gat
# Processing Record 39 of Set 10 | carnduff
# Processing Record 40 of Set 10 | kovdor
# Processing Record 41 of Set 10 | manzanillo
# Processing Record 42 of Set 10 | leh
# Processing Record 43 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 10 | shaunavon
# Processing Record 45 of Set 10 | virden
# Processing Record 46 of Set 10 | kruisfontein
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | diffa
# Processing Record 49 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 10 | puri
# Processing Record 1 of Set 11 | nanga eboko
# Processing Record 2 of Set 11 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 3 of Set 11 | kafanchan
# Processing Record 4 of Set 11 | khartoum
# Processing Record 5 of Set 11 | nelson bay
# Processing Record 6 of Set 11 | horsham
# Processing Record 7 of Set 11 | kalemie
# Processing Record 8 of Set 11 | ratnagiri
# Processing Record 9 of Set 11 | sabzevar
# Processing Record 10 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | pokrovsk
# Processing Record 13 of Set 11 | lulea
# Processing Record 14 of Set 11 | misratah
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | oksfjord
# Processing Record 17 of Set 11 | rossland
# Processing Record 18 of Set 11 | roald
# Processing Record 19 of Set 11 | raga
# Processing Record 20 of Set 11 | fairview
# Processing Record 21 of Set 11 | los llanos de aridane
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | broome
# Processing Record 24 of Set 11 | wenling
# Processing Record 25 of Set 11 | ixtapa
# Processing Record 26 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 27 of Set 11 | berdigestyakh
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | shenandoah
# Processing Record 30 of Set 11 | soe
# Processing Record 31 of Set 11 | beloha
# Processing Record 32 of Set 11 | smithers
# Processing Record 33 of Set 11 | stokmarknes
# Processing Record 34 of Set 11 | payakumbuh
# Processing Record 35 of Set 11 | north bend
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | coolum beach
# Processing Record 38 of Set 11 | sri aman
# Processing Record 39 of Set 11 | shitanjing
# Processing Record 40 of Set 11 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 41 of Set 11 | astana
# Processing Record 42 of Set 11 | kyaikkami
# Processing Record 43 of Set 11 | paamiut
# Processing Record 44 of Set 11 | olga
# Processing Record 45 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 11 | garowe
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | mount isa
# Processing Record 50 of Set 11 | phan thiet
# Processing Record 1 of Set 12 | sfantu gheorghe
# Processing Record 2 of Set 12 | lasem
# Processing Record 3 of Set 12 | bay roberts
# Processing Record 4 of Set 12 | manggar
# Processing Record 5 of Set 12 | tucupita
# Processing Record 6 of Set 12 | khuzdar
# Processing Record 7 of Set 12 | ransang
# Processing Record 8 of Set 12 | chesma
# Processing Record 9 of Set 12 | honiara
# Processing Record 10 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 12 | caranavi
# Processing Record 12 of Set 12 | aqtobe
# Processing Record 13 of Set 12 | baruun-urt
# Processing Record 14 of Set 12 | harstad
# Processing Record 15 of Set 12 | imbituba
# Processing Record 16 of Set 12 | kasongo-lunda
# Processing Record 17 of Set 12 | ales
# Processing Record 18 of Set 12 | north platte
# Processing Record 19 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 12 | sanming
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | kahului
# Processing Record 23 of Set 12 | kamarion
# Processing Record 24 of Set 12 | port hardy
# Processing Record 25 of Set 12 | ryazanskaya
# Processing Record 26 of Set 12 | kuruman
# Processing Record 27 of Set 12 | phalodi
# Processing Record 28 of Set 12 | ushtobe
# Processing Record 29 of Set 12 | nikel
# Processing Record 30 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 31 of Set 12 | sisimiut
# Processing Record 32 of Set 12 | kazerun
# Processing Record 33 of Set 12 | rio grande
# Processing Record 34 of Set 12 | ambilobe
# Processing Record 35 of Set 12 | dingle
# Processing Record 36 of Set 12 | port moresby
# Processing Record 37 of Set 12 | ferrol
# Processing Record 38 of Set 12 | sao joao da barra
# Processing Record 39 of Set 12 | dunmore east
# Processing Record 40 of Set 12 | teguldet
# Processing Record 41 of Set 12 | ragay
# Processing Record 42 of Set 12 | caserta
# Processing Record 43 of Set 12 | namatanai
# Processing Record 44 of Set 12 | taoudenni
# Processing Record 45 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | hanzhong
# Processing Record 47 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | vanavara
# Processing Record 49 of Set 12 | pimenta bueno
# Processing Record 50 of Set 12 | morgan city
# Processing Record 1 of Set 13 | capaci
# Processing Record 2 of Set 13 | hopkinsville
# Processing Record 3 of Set 13 | marawi
# Processing Record 4 of Set 13 | chenzhou
# Processing Record 5 of Set 13 | vardo
# Processing Record 6 of Set 13 | saint-joseph
# Processing Record 7 of Set 13 | vale da amoreira
# Processing Record 8 of Set 13 | qasigiannguit
# Processing Record 9 of Set 13 | sobolevo
# Processing Record 10 of Set 13 | coquimbo
# Processing Record 11 of Set 13 | sao gabriel da cachoeira
# Processing Record 12 of Set 13 | korcula
# Processing Record 13 of Set 13 | volodarka
# Processing Record 14 of Set 13 | deputatskiy
# Processing Record 15 of Set 13 | mitsamiouli
# Processing Record 16 of Set 13 | wum
# Processing Record 17 of Set 13 | santa clara
# Processing Record 18 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 13 | slovenske konjice
# Processing Record 20 of Set 13 | kibakwe
# Processing Record 21 of Set 13 | ulaanbaatar
# Processing Record 22 of Set 13 | borodino
# Processing Record 23 of Set 13 | tomatlan
# Processing Record 24 of Set 13 | namibe
# Processing Record 25 of Set 13 | nizhnyaya poyma
# Processing Record 26 of Set 13 | oranjestad
# Processing Record 27 of Set 13 | verkhoyansk
# Processing Record 28 of Set 13 | grand gaube
# Processing Record 29 of Set 13 | korgen
# Processing Record 30 of Set 13 | tual
# Processing Record 31 of Set 13 | high level
# Processing Record 32 of Set 13 | porto san giorgio
# Processing Record 33 of Set 13 | sioux lookout
# Processing Record 34 of Set 13 | mumford
# Processing Record 35 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 13 | bronnoysund
# Processing Record 37 of Set 13 | nouadhibou
# Processing Record 38 of Set 13 | venice
# Processing Record 39 of Set 13 | lunao
# Processing Record 40 of Set 13 | tocopilla
# Processing Record 41 of Set 13 | alenquer
# Processing Record 42 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 43 of Set 13 | teluknaga
# Processing Record 44 of Set 13 | nanortalik
# Processing Record 45 of Set 13 | talara
# Processing Record 46 of Set 13 | casa nova
# Processing Record 47 of Set 13 | jining
# Processing Record 48 of Set 13 | fairbanks
# Processing Record 49 of Set 13 | kjopsvik
# Processing Record 50 of Set 13 | sorland
# Processing Record 1 of Set 14 | miri
# Processing Record 2 of Set 14 | mingguang
# Processing Record 3 of Set 14 | raudeberg
# Processing Record 4 of Set 14 | puunsi
# City not found. Skipping...
# Processing Record 5 of Set 14 | kayerkan
# Processing Record 6 of Set 14 | kedougou
# Processing Record 7 of Set 14 | formosa
# Processing Record 8 of Set 14 | huancavelica
# Processing Record 9 of Set 14 | mawlaik
# Processing Record 10 of Set 14 | katangli
# Processing Record 11 of Set 14 | yining
# Processing Record 12 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 14 | krasnyy kholm
# Processing Record 14 of Set 14 | ipixuna
# Processing Record 15 of Set 14 | dayong
# Processing Record 16 of Set 14 | moctezuma
# Processing Record 17 of Set 14 | luganville
# Processing Record 18 of Set 14 | gurlan
# Processing Record 19 of Set 14 | bukama
# Processing Record 20 of Set 14 | uncia
# Processing Record 21 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 14 | grindavik
# Processing Record 23 of Set 14 | meybod
# Processing Record 24 of Set 14 | rio gallegos
# Processing Record 25 of Set 14 | borogontsy
# Processing Record 26 of Set 14 | ukiah
# Processing Record 27 of Set 14 | beruwala
# Processing Record 28 of Set 14 | coihaique
# Processing Record 29 of Set 14 | venado tuerto
# Processing Record 30 of Set 14 | goya
# Processing Record 31 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 14 | santa lucia
# Processing Record 34 of Set 14 | kenai
# Processing Record 35 of Set 14 | romny
# Processing Record 36 of Set 14 | port-gentil
# Processing Record 37 of Set 14 | wanning
# Processing Record 38 of Set 14 | shemonaikha
# Processing Record 39 of Set 14 | ati
# Processing Record 40 of Set 14 | russell
# Processing Record 41 of Set 14 | hailin
# Processing Record 42 of Set 14 | belyy yar
# Processing Record 43 of Set 14 | fort frances
# Processing Record 44 of Set 14 | kabanjahe
# Processing Record 45 of Set 14 | nemuro
# Processing Record 46 of Set 14 | marrakesh
# Processing Record 47 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 14 | capanema
# Processing Record 49 of Set 14 | acapulco
# Processing Record 50 of Set 14 | mazagao
# Processing Record 1 of Set 15 | itupiranga
# Processing Record 2 of Set 15 | mocuba
# Processing Record 3 of Set 15 | tadepallegudem
# Processing Record 4 of Set 15 | morondava
# Processing Record 5 of Set 15 | sapa
# Processing Record 6 of Set 15 | yenotayevka
# Processing Record 7 of Set 15 | roswell
# Processing Record 8 of Set 15 | bandarbeyla
# Processing Record 9 of Set 15 | benguela
# Processing Record 10 of Set 15 | kuanshan
# City not found. Skipping...
# Processing Record 11 of Set 15 | alice springs
# Processing Record 12 of Set 15 | prince rupert
# Processing Record 13 of Set 15 | ucluelet
# Processing Record 14 of Set 15 | weligama
# Processing Record 15 of Set 15 | vila
# Processing Record 16 of Set 15 | lakatoro
# Processing Record 17 of Set 15 | brekstad
# Processing Record 18 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 19 of Set 15 | dori
# Processing Record 20 of Set 15 | yanam
# Processing Record 21 of Set 15 | muros
# Processing Record 22 of Set 15 | te anau
# Processing Record 23 of Set 15 | lubuagan
# Processing Record 24 of Set 15 | bara
# Processing Record 25 of Set 15 | miyako
# Processing Record 26 of Set 15 | serafimovich
# Processing Record 27 of Set 15 | matamoros
# Processing Record 28 of Set 15 | witu
# Processing Record 29 of Set 15 | solnechnyy
# Processing Record 30 of Set 15 | yumen
# Processing Record 31 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 15 | dusti
# Processing Record 33 of Set 15 | gisborne
# Processing Record 34 of Set 15 | orlik
# Processing Record 35 of Set 15 | port alberni
# Processing Record 36 of Set 15 | fort nelson
# Processing Record 37 of Set 15 | san policarpo
# Processing Record 38 of Set 15 | rochegda
# Processing Record 39 of Set 15 | bud
# Processing Record 40 of Set 15 | pecos
# Processing Record 41 of Set 15 | kamaishi
# Processing Record 42 of Set 15 | gannan
# Processing Record 43 of Set 15 | suluq
# Processing Record 44 of Set 15 | santa isabel do rio negro
# Processing Record 45 of Set 15 | biltine
# Processing Record 46 of Set 15 | thonon-les-bains
# Processing Record 47 of Set 15 | brigantine
# Processing Record 48 of Set 15 | hit
# Processing Record 49 of Set 15 | kelo
# Processing Record 50 of Set 15 | divnomorskoye
# Processing Record 1 of Set 16 | awjilah
# Processing Record 2 of Set 16 | atchison
# Processing Record 3 of Set 16 | poltsamaa
# Processing Record 4 of Set 16 | bayir
# Processing Record 5 of Set 16 | takoradi
# Processing Record 6 of Set 16 | at-bashi
# Processing Record 7 of Set 16 | safaga
# Processing Record 8 of Set 16 | bilma
# Processing Record 9 of Set 16 | waingapu
# Processing Record 10 of Set 16 | amahai
# Processing Record 11 of Set 16 | xichang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Current Description      Lat       Lng  Max Temp  Humidity  \
# 0        Mataura       broken clouds -46.1927  168.8643     66.15        52
# 1       Hermanus     overcast clouds -34.4187   19.2345     54.81        89
# 2    New Norfolk       broken clouds -42.7826  147.0587     62.71        68
# 3     Chokurdakh     overcast clouds  70.6333  147.9167     32.95        68
# 4     Porto Belo     overcast clouds -27.1578  -48.5531     58.15        92
# 5  Mar Del Plata                mist -38.0023  -57.5575     55.09        97
# 6          Vaini       moderate rain -21.2000 -175.2000     73.56       100
# 7          Lagoa     overcast clouds  39.0500  -27.9833     69.84        70
# 8        Ushuaia       broken clouds -54.8000  -68.3000     46.06        61
# 9   Puerto Ayora     overcast clouds  -0.7393  -90.3518     66.54        95
#
#    Cloudiness  Wind Speed Country                 Date
# 0          82        1.63      NZ  2022-09-26 02:23:48
# 1          98        7.34      ZA  2022-09-26 02:23:44
# 2          64        1.01      AU  2022-09-26 02:24:35
# 3          91       13.49      RU  2022-09-26 02:23:58
# 4         100        7.25      BR  2022-09-26 02:30:41
# 5          75        8.05      AR  2022-09-26 02:23:36
# 6         100        6.91      TO  2022-09-26 02:23:42
# 7         100       20.83      PT  2022-09-26 02:26:46
# 8          75        2.30      AR  2022-09-26 02:23:31
# 9         100        8.99      EC  2022-09-26 02:25:22

# %%
# create variable for new column order

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# reorder columns in the city data dataframe

city_data_df = city_data_df[new_column_order] 
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura      NZ -46.1927  168.8643     66.15        52          82
# 1       Hermanus      ZA -34.4187   19.2345     54.81        89          98
# 2    New Norfolk      AU -42.7826  147.0587     62.71        68          64
# 3     Chokurdakh      RU  70.6333  147.9167     32.95        68          91
# 4     Porto Belo      BR -27.1578  -48.5531     58.15        92         100
# 5  Mar Del Plata      AR -38.0023  -57.5575     55.09        97          75
# 6          Vaini      TO -21.2000 -175.2000     73.56       100         100
# 7          Lagoa      PT  39.0500  -27.9833     69.84        70         100
# 8        Ushuaia      AR -54.8000  -68.3000     46.06        61          75
# 9   Puerto Ayora      EC  -0.7393  -90.3518     66.54        95         100
#
#    Wind Speed Current Description
# 0        1.63       broken clouds
# 1        7.34     overcast clouds
# 2        1.01       broken clouds
# 3       13.49     overcast clouds
# 4        7.25     overcast clouds
# 5        8.05                mist
# 6        6.91       moderate rain
# 7       20.83     overcast clouds
# 8        2.30       broken clouds
# 9        8.99     overcast clouds

# %%
# create the output file (CSV)

output_data_file = "WeatherPY_Database.csv"

# export the City_Data into a CSV

city_data_df.to_csv(output_data_file, index_label="City_ID")
